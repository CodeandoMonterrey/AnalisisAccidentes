# %%
import pandas as pd
import numpy as np

# %%
data_nueva = pd.read_excel("25_mayo.xlsx")

# %%
data_vieja = pd.read_excel("tabla_previa.xls")

# %%
data_nueva.columns
# Out:
# Index(['ID', 'Ciudad', 'Mes', 'Fecha', 'Hora', 'Longitud', 'Latitud', 'Calle',
#        'Cruce', 'Sentido', 'V1_Tipo de Vehículo', 'V1_Estatus Licencia',
#        'V1_Género', 'V1_Dictamen', 'V1_Edad', 'V1_Uso de Cinturón',
#        'V1_Arresto', 'V1_No. De Lesionados', 'V1_No. De Fallecidos',
#        'V2_Tipo de Vehículo', 'V2_Estatus Licencia', 'V2_Género',
#        'V2_Dictamen', 'V2_Edad', 'V2_Uso de Cinturón', 'V2_Arresto',
#        'V2_No. De Lesionados', 'V2_No. De Fallecidos', 'V3_Tipo de Vehículo',
#        'V3_Estatus Licencia', 'V3_Género', 'V3_Dictamen', 'V3_Edad',
#        'V3_Uso de Cinturón', 'V3_Arresto', 'V3_No. De Lesionados',
#        'V3_No. De Fallecidos', 'Tipo de incidente', 'No. De Infracción',
#        'Causa', 'Situación climática', 'Situación del Pavimento',
#        'Tipo de vía', 'Número  total de lesionados', 'Número total de muertos',
#        'Column', 'Column2', 'Column3', 'Column4', 'Column5', 'Column6',
# ...

# %%
len(data_nueva)
# Out:
# 25256

# %%
columns_vieja = list(data_vieja.columns)

# %%
columns_nueva = list(data_nueva.columns)[0:45]

# %%
data_nueva = data_nueva[columns_nueva]

# %%
 result = pd.concat([ data_vieja, data_nueva])

# %%
result
# Out:
#                              Calle                             Causa  \
# 0                      CAMINO REAL         NO REPSETAR SEÑALAMIENTOS
# 1                   BERNARDO REYES                             Otros
# 2                   BERNARDO REYES                             Otros
# 3                          LINCOLN                    INVADIR CARRIL
# 4                           MADERO              NO GUARDAR DISTANCIA
# 5                       REVOLUCION               No Respetó Semáforo
# 6      ANT CAM A VILLA DE SANTIAGO              NO GUARDAR DISTANCIA
# 7                       CHURUBUSCO              NO GUARDAR DISTANCIA
# 8                       LAS FLORES                    INVADIR CARRIL
# 9                          COLOSIO                             Otros
# 10                          LEONES                    INVADIR CARRIL
# 11                   ALFONSO REYES                             Otros
# 12                      GARZA SADA              NO GUARDAR DISTANCIA
# ...

# %%
result.to_excel("All_data.xls")

# %%
result.to_csv("All_data_csv.csv")
